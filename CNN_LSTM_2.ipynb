# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, TimeDistributed, Conv1D, LSTM, MaxPooling1D, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import regularizers
from tensorflow.keras.layers import LeakyReLU
# from tensorflow_addons.optimizers import CyclicalLearningRate
import glob
import os
import csv

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    print(gpu)
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
def merge_csi_label(csifile, labelfile, win_len=300, thrshd=0.6, step=50):
    activity = []
    with open(labelfile, 'r') as labelf:
        reader = csv.reader(labelf)
        for line in reader:
            label  = line[0]
            if label == 'NoActivity':
                activity.append(0)
            else:
                activity.append(1)
    activity = np.array(activity)
    csi = []
    with open(csifile, 'r') as csif:
        reader = csv.reader(csif)
        for line in reader:
            line_array = np.array([float(v) for v in line])
            # extract the amplitude only
            line_array = line_array[0:52]
            csi.append(line_array[np.newaxis,...])
    csi = np.concatenate(csi, axis=0)
    assert(csi.shape[0] == activity.shape[0])
    # screen the data with a window
    index = 0
    feature = []
    while index + win_len <= csi.shape[0]:
        cur_activity = activity[index:index+win_len]
        if np.sum(cur_activity)  <  thrshd * win_len:
            index += step
            continue
        cur_feature = np.zeros((1, win_len, 52))
        cur_feature[0] = csi[index:index+win_len, :]
        feature.append(cur_feature)
        index += step
    return np.concatenate(feature, axis=0)

# %%
def extract_csi_by_label(raw_folder, label, labels, save=False, win_len=300, thrshd=0.6, step=50):
    print('Starting Extract CSI for Label {}'.format(label))
    label = label.lower()
    if not label in labels:
        raise ValueError("The label {} should be among 'lie down','fall','bend','run','sitdown','standup','walk'".format(labels))
    data_path_pattern = os.path.join(raw_folder,label, 'user_*' + label + '*.csv')
    input_csv_files = sorted(glob.glob(data_path_pattern))
    # annot_csv_files = [os.path.basename(fname).replace('user_', 'annotation_user') for fname in input_csv_files]
    # annot_csv_files = [os.path.join(raw_folder, label, fname) for fname in annot_csv_files]
    annot_csv_files = os.path.join(raw_folder,label, 'Annotation_user_*' + label + '*.csv')
    annot_csv_files = sorted(glob.glob(annot_csv_files))
    feature = []
    index = 0
    for csi_file, label_file in zip(input_csv_files, annot_csv_files):
        index += 1
        if not os.path.exists(label_file):
            print('Warning! Label File {} doesn\'t exist.'.format(label_file))
            continue
        feature.append(merge_csi_label(csi_file, label_file, win_len=win_len, thrshd=thrshd, step=step))
        print('Finished {:.2f}% for Label {}'.format(index / len(input_csv_files) * 100,label))
    
    feat_arr = np.concatenate(feature, axis=0)
    if save:
        np.savez_compressed("X_{}.npz".format(label), feat_arr)
    # one hot
    feat_label = np.zeros((feat_arr.shape[0], len(labels)))
    feat_label[:, labels.index(label)] = 1
    return feat_arr, feat_label

# %%
def extract_csi(raw_folder, labels, save=False, win_len=300, thrshd=0.6, step=50):
    ans = []
    for label in labels:
        feature_arr, label_arr = extract_csi_by_label(raw_folder, label, labels, save, win_len, thrshd, step)
        ans.append(feature_arr)
        ans.append(label_arr)
    return tuple(ans)

# %%
class CSIModelConfig:
    def __init__(self, win_len=300, step=50, thrshd=0.6):
        self._win_len = win_len
        self._step = step
        self._thrshd = thrshd
        self._labels = ("lie down", "fall", "bend", "run", "sitdown", "standup", "walk")
        # self._downsample = downsample

    def preprocessing(self, raw_folder, save=False):
        numpy_tuple = extract_csi(raw_folder, self._labels, save, self._win_len, self._thrshd, self._step)
        # if self._downsample > 1:
        #     return tuple([v[:, ::self._downsample,...] if i%2 ==0 else v for i, v in enumerate(numpy_tuple)])
        return numpy_tuple
    
    def load_csi_data_from_files(self, np_files):
        if len(np_files) != 7:
            raise ValueError('There should be 7 numpy files for lie down, fall, bend, run, sitdown, standup, walk.')
        x = [np.load(f)['arr_0'] for f in np_files]
        # if self._downsample > 1:
        #     x = [arr[:,::self._downsample, :] for arr in x]
        y = [np.zeros((arr.shape[0], len(self._labels))) for arr in x]
        numpy_list = []
        for i in range(len(self._labels)):
            y[i][:,i] = 1
            numpy_list.append(x[i])
            numpy_list.append(y[i])
        return tuple(numpy_list)

# %%
def train_valid_split(numpy_tuple, train_portion=0.8, seed=200):
    np.random.seed(seed=seed)
    x_train = []
    x_valid = []
    y_valid = []
    y_train = []

    for i, x_arr in enumerate(numpy_tuple):
        index = np.random.permutation([i for i in range(x_arr.shape[0])])
        split_len = int(train_portion * x_arr.shape[0])
        x_train.append(x_arr[index[:split_len], ...])
        tmpy = np.zeros((split_len,7))
        tmpy[:, i] = 1
        y_train.append(tmpy)
        x_valid.append(x_arr[index[split_len:],...])
        tmpy = np.zeros((x_arr.shape[0]-split_len,7))
        tmpy[:, i] = 1
        y_valid.append(tmpy)
    
    x_train = np.concatenate(x_train, axis=0)
    y_train = np.concatenate(y_train, axis=0)
    x_valid = np.concatenate(x_valid, axis=0)
    y_valid = np.concatenate(y_valid, axis=0)

    index = np.random.permutation([i for i in range(x_train.shape[0])])
    x_train = x_train[index, ...]
    y_train = y_train[index, ...]
    return x_train, y_train, x_valid, y_valid

# %%
cfg = CSIModelConfig(win_len=300, step=50, thrshd=0.65)
numpy_tuple = cfg.preprocessing('CSI-HAR-Dataset', save=True)

x_lie_down, y_lie_down, x_fall, y_fall, x_bend, y_bend, x_run, y_run, x_sitdown, y_sitdown, x_standup, y_standup, x_walk, y_walk = numpy_tuple
x_train, y_train, x_valid, y_valid = train_valid_split((x_lie_down, x_fall, x_bend, x_run, x_sitdown, x_standup, x_walk),train_portion=0.8, seed=200)
n_timesteps, n_features, n_outputs = x_train.shape[1], x_train.shape[2], y_train.shape[1]
# Out:
# Starting Extract CSI for Label lie down
# Finished 1.67% for Label lie down
# Finished 3.33% for Label lie down
# Finished 5.00% for Label lie down
# Finished 6.67% for Label lie down
# Finished 8.33% for Label lie down
# Finished 10.00% for Label lie down
# Finished 11.67% for Label lie down
# Finished 13.33% for Label lie down
# Finished 15.00% for Label lie down
# Finished 16.67% for Label lie down
# Finished 18.33% for Label lie down
# Finished 20.00% for Label lie down
# Finished 21.67% for Label lie down
# Finished 23.33% for Label lie down
# Finished 25.00% for Label lie down
# Finished 26.67% for Label lie down
# Finished 28.33% for Label lie down
# Finished 30.00% for Label lie down
# Finished 31.67% for Label lie down
# Finished 33.33% for Label lie down
# Finished 35.00% for Label lie down
# Finished 36.67% for Label lie down
# Finished 38.33% for Label lie down
# Finished 40.00% for Label lie down
# Finished 41.67% for Label lie down
# Finished 43.33% for Label lie down
# Finished 45.00% for Label lie down
# Finished 46.67% for Label lie down
# Finished 48.33% for Label lie down
# Finished 50.00% for Label lie down
# Finished 51.67% for Label lie down
# Finished 53.33% for Label lie down
# Finished 55.00% for Label lie down
# Finished 56.67% for Label lie down
# Finished 58.33% for Label lie down
# Finished 60.00% for Label lie down
# Finished 61.67% for Label lie down
# Finished 63.33% for Label lie down
# Finished 65.00% for Label lie down
# Finished 66.67% for Label lie down
# Finished 68.33% for Label lie down
# Finished 70.00% for Label lie down
# Finished 71.67% for Label lie down
# Finished 73.33% for Label lie down
# Finished 75.00% for Label lie down
# Finished 76.67% for Label lie down
# Finished 78.33% for Label lie down
# Finished 80.00% for Label lie down
# Finished 81.67% for Label lie down
# Finished 83.33% for Label lie down
# Finished 85.00% for Label lie down
# Finished 86.67% for Label lie down
# Finished 88.33% for Label lie down
# Finished 90.00% for Label lie down
# Finished 91.67% for Label lie down
# Finished 93.33% for Label lie down
# Finished 95.00% for Label lie down
# Finished 96.67% for Label lie down
# Finished 98.33% for Label lie down
# Finished 100.00% for Label lie down
# Starting Extract CSI for Label fall
# Finished 1.67% for Label fall
# Finished 3.33% for Label fall
# Finished 5.00% for Label fall
# Finished 6.67% for Label fall
# Finished 8.33% for Label fall
# Finished 10.00% for Label fall
# Finished 11.67% for Label fall
# Finished 13.33% for Label fall
# Finished 15.00% for Label fall
# Finished 16.67% for Label fall
# Finished 18.33% for Label fall
# Finished 20.00% for Label fall
# Finished 21.67% for Label fall
# Finished 23.33% for Label fall
# Finished 25.00% for Label fall
# Finished 26.67% for Label fall
# Finished 28.33% for Label fall
# Finished 30.00% for Label fall
# Finished 31.67% for Label fall
# Finished 33.33% for Label fall
# Finished 35.00% for Label fall
# Finished 36.67% for Label fall
# Finished 38.33% for Label fall
# Finished 40.00% for Label fall
# Finished 41.67% for Label fall
# Finished 43.33% for Label fall
# Finished 45.00% for Label fall
# Finished 46.67% for Label fall
# Finished 48.33% for Label fall
# Finished 50.00% for Label fall
# Finished 51.67% for Label fall
# Finished 53.33% for Label fall
# Finished 55.00% for Label fall
# Finished 56.67% for Label fall
# Finished 58.33% for Label fall
# Finished 60.00% for Label fall
# Finished 61.67% for Label fall
# Finished 63.33% for Label fall
# Finished 65.00% for Label fall
# Finished 66.67% for Label fall
# Finished 68.33% for Label fall
# Finished 70.00% for Label fall
# Finished 71.67% for Label fall
# Finished 73.33% for Label fall
# Finished 75.00% for Label fall
# Finished 76.67% for Label fall
# Finished 78.33% for Label fall
# Finished 80.00% for Label fall
# Finished 81.67% for Label fall
# Finished 83.33% for Label fall
# Finished 85.00% for Label fall
# Finished 86.67% for Label fall
# Finished 88.33% for Label fall
# Finished 90.00% for Label fall
# Finished 91.67% for Label fall
# Finished 93.33% for Label fall
# Finished 95.00% for Label fall
# Finished 96.67% for Label fall
# Finished 98.33% for Label fall
# Finished 100.00% for Label fall
# Starting Extract CSI for Label bend
# Finished 1.67% for Label bend
# Finished 3.33% for Label bend
# Finished 5.00% for Label bend
# Finished 6.67% for Label bend
# Finished 8.33% for Label bend
# Finished 10.00% for Label bend
# Finished 11.67% for Label bend
# Finished 13.33% for Label bend
# Finished 15.00% for Label bend
# Finished 16.67% for Label bend
# Finished 18.33% for Label bend
# Finished 20.00% for Label bend
# Finished 21.67% for Label bend
# Finished 23.33% for Label bend
# Finished 25.00% for Label bend
# Finished 26.67% for Label bend
# Finished 28.33% for Label bend
# Finished 30.00% for Label bend
# Finished 31.67% for Label bend
# Finished 33.33% for Label bend
# Finished 35.00% for Label bend
# Finished 36.67% for Label bend
# Finished 38.33% for Label bend
# Finished 40.00% for Label bend
# Finished 41.67% for Label bend
# Finished 43.33% for Label bend
# Finished 45.00% for Label bend
# Finished 46.67% for Label bend
# Finished 48.33% for Label bend
# Finished 50.00% for Label bend
# Finished 51.67% for Label bend
# Finished 53.33% for Label bend
# Finished 55.00% for Label bend
# Finished 56.67% for Label bend
# Finished 58.33% for Label bend
# Finished 60.00% for Label bend
# Finished 61.67% for Label bend
# Finished 63.33% for Label bend
# Finished 65.00% for Label bend
# Finished 66.67% for Label bend
# Finished 68.33% for Label bend
# Finished 70.00% for Label bend
# Finished 71.67% for Label bend
# Finished 73.33% for Label bend
# Finished 75.00% for Label bend
# Finished 76.67% for Label bend
# Finished 78.33% for Label bend
# Finished 80.00% for Label bend
# Finished 81.67% for Label bend
# Finished 83.33% for Label bend
# Finished 85.00% for Label bend
# Finished 86.67% for Label bend
# Finished 88.33% for Label bend
# Finished 90.00% for Label bend
# Finished 91.67% for Label bend
# Finished 93.33% for Label bend
# Finished 95.00% for Label bend
# Finished 96.67% for Label bend
# Finished 98.33% for Label bend
# Finished 100.00% for Label bend
# Starting Extract CSI for Label run
# Finished 1.67% for Label run
# Finished 3.33% for Label run
# Finished 5.00% for Label run
# Finished 6.67% for Label run
# Finished 8.33% for Label run
# Finished 10.00% for Label run
# Finished 11.67% for Label run
# Finished 13.33% for Label run
# Finished 15.00% for Label run
# Finished 16.67% for Label run
# Finished 18.33% for Label run
# Finished 20.00% for Label run
# Finished 21.67% for Label run
# Finished 23.33% for Label run
# Finished 25.00% for Label run
# Finished 26.67% for Label run
# Finished 28.33% for Label run
# Finished 30.00% for Label run
# Finished 31.67% for Label run
# Finished 33.33% for Label run
# Finished 35.00% for Label run
# Finished 36.67% for Label run
# Finished 38.33% for Label run
# Finished 40.00% for Label run
# Finished 41.67% for Label run
# Finished 43.33% for Label run
# Finished 45.00% for Label run
# Finished 46.67% for Label run
# Finished 48.33% for Label run
# Finished 50.00% for Label run
# Finished 51.67% for Label run
# Finished 53.33% for Label run
# Finished 55.00% for Label run
# Finished 56.67% for Label run
# Finished 58.33% for Label run
# Finished 60.00% for Label run
# Finished 61.67% for Label run
# Finished 63.33% for Label run
# Finished 65.00% for Label run
# Finished 66.67% for Label run
# Finished 68.33% for Label run
# Finished 70.00% for Label run
# Finished 71.67% for Label run
# Finished 73.33% for Label run
# Finished 75.00% for Label run
# Finished 76.67% for Label run
# Finished 78.33% for Label run
# Finished 80.00% for Label run
# Finished 81.67% for Label run
# Finished 83.33% for Label run
# Finished 85.00% for Label run
# Finished 86.67% for Label run
# Finished 88.33% for Label run
# Finished 90.00% for Label run
# Finished 91.67% for Label run
# Finished 93.33% for Label run
# Finished 95.00% for Label run
# Finished 96.67% for Label run
# Finished 98.33% for Label run
# Finished 100.00% for Label run
# Starting Extract CSI for Label sitdown
# Finished 1.67% for Label sitdown
# Finished 3.33% for Label sitdown
# Finished 5.00% for Label sitdown
# Finished 6.67% for Label sitdown
# Finished 8.33% for Label sitdown
# Finished 10.00% for Label sitdown
# Finished 11.67% for Label sitdown
# Finished 13.33% for Label sitdown
# Finished 15.00% for Label sitdown
# Finished 16.67% for Label sitdown
# Finished 18.33% for Label sitdown
# Finished 20.00% for Label sitdown
# Finished 21.67% for Label sitdown
# Finished 23.33% for Label sitdown
# Finished 25.00% for Label sitdown
# Finished 26.67% for Label sitdown
# Finished 28.33% for Label sitdown
# Finished 30.00% for Label sitdown
# Finished 31.67% for Label sitdown
# Finished 33.33% for Label sitdown
# Finished 35.00% for Label sitdown
# Finished 36.67% for Label sitdown
# Finished 38.33% for Label sitdown
# Finished 40.00% for Label sitdown
# Finished 41.67% for Label sitdown
# Finished 43.33% for Label sitdown
# Finished 45.00% for Label sitdown
# Finished 46.67% for Label sitdown
# Finished 48.33% for Label sitdown
# Finished 50.00% for Label sitdown
# Finished 51.67% for Label sitdown
# Finished 53.33% for Label sitdown
# Finished 55.00% for Label sitdown
# Finished 56.67% for Label sitdown
# Finished 58.33% for Label sitdown
# Finished 60.00% for Label sitdown
# Finished 61.67% for Label sitdown
# Finished 63.33% for Label sitdown
# Finished 65.00% for Label sitdown
# Finished 66.67% for Label sitdown
# Finished 68.33% for Label sitdown
# Finished 70.00% for Label sitdown
# Finished 71.67% for Label sitdown
# Finished 73.33% for Label sitdown
# Finished 75.00% for Label sitdown
# Finished 76.67% for Label sitdown
# Finished 78.33% for Label sitdown
# Finished 80.00% for Label sitdown
# Finished 81.67% for Label sitdown
# Finished 83.33% for Label sitdown
# Finished 85.00% for Label sitdown
# Finished 86.67% for Label sitdown
# Finished 88.33% for Label sitdown
# Finished 90.00% for Label sitdown
# Finished 91.67% for Label sitdown
# Finished 93.33% for Label sitdown
# Finished 95.00% for Label sitdown
# Finished 96.67% for Label sitdown
# Finished 98.33% for Label sitdown
# Finished 100.00% for Label sitdown
# Starting Extract CSI for Label standup
# Finished 1.67% for Label standup
# Finished 3.33% for Label standup
# Finished 5.00% for Label standup
# Finished 6.67% for Label standup
# Finished 8.33% for Label standup
# Finished 10.00% for Label standup
# Finished 11.67% for Label standup
# Finished 13.33% for Label standup
# Finished 15.00% for Label standup
# Finished 16.67% for Label standup
# Finished 18.33% for Label standup
# Finished 20.00% for Label standup
# Finished 21.67% for Label standup
# Finished 23.33% for Label standup
# Finished 25.00% for Label standup
# Finished 26.67% for Label standup
# Finished 28.33% for Label standup
# Finished 30.00% for Label standup
# Finished 31.67% for Label standup
# Finished 33.33% for Label standup
# Finished 35.00% for Label standup
# Finished 36.67% for Label standup
# Finished 38.33% for Label standup
# Finished 40.00% for Label standup
# Finished 41.67% for Label standup
# Finished 43.33% for Label standup
# Finished 45.00% for Label standup
# Finished 46.67% for Label standup
# Finished 48.33% for Label standup
# Finished 50.00% for Label standup
# Finished 51.67% for Label standup
# Finished 53.33% for Label standup
# Finished 55.00% for Label standup
# Finished 56.67% for Label standup
# Finished 58.33% for Label standup
# Finished 60.00% for Label standup
# Finished 61.67% for Label standup
# Finished 63.33% for Label standup
# Finished 65.00% for Label standup
# Finished 66.67% for Label standup
# Finished 68.33% for Label standup
# Finished 70.00% for Label standup
# Finished 71.67% for Label standup
# Finished 73.33% for Label standup
# Finished 75.00% for Label standup
# Finished 76.67% for Label standup
# Finished 78.33% for Label standup
# Finished 80.00% for Label standup
# Finished 81.67% for Label standup
# Finished 83.33% for Label standup
# Finished 85.00% for Label standup
# Finished 86.67% for Label standup
# Finished 88.33% for Label standup
# Finished 90.00% for Label standup
# Finished 91.67% for Label standup
# Finished 93.33% for Label standup
# Finished 95.00% for Label standup
# Finished 96.67% for Label standup
# Finished 98.33% for Label standup
# Finished 100.00% for Label standup
# Starting Extract CSI for Label walk
# Finished 1.67% for Label walk
# Finished 3.33% for Label walk
# Finished 5.00% for Label walk
# Finished 6.67% for Label walk
# Finished 8.33% for Label walk
# Finished 10.00% for Label walk
# Finished 11.67% for Label walk
# Finished 13.33% for Label walk
# Finished 15.00% for Label walk
# Finished 16.67% for Label walk
# Finished 18.33% for Label walk
# Finished 20.00% for Label walk
# Finished 21.67% for Label walk
# Finished 23.33% for Label walk
# Finished 25.00% for Label walk
# Finished 26.67% for Label walk
# Finished 28.33% for Label walk
# Finished 30.00% for Label walk
# Finished 31.67% for Label walk
# Finished 33.33% for Label walk
# Finished 35.00% for Label walk
# Finished 36.67% for Label walk
# Finished 38.33% for Label walk
# Finished 40.00% for Label walk
# Finished 41.67% for Label walk
# Finished 43.33% for Label walk
# Finished 45.00% for Label walk
# Finished 46.67% for Label walk
# Finished 48.33% for Label walk
# Finished 50.00% for Label walk
# Finished 51.67% for Label walk
# Finished 53.33% for Label walk
# Finished 55.00% for Label walk
# Finished 56.67% for Label walk
# Finished 58.33% for Label walk
# Finished 60.00% for Label walk
# Finished 61.67% for Label walk
# Finished 63.33% for Label walk
# Finished 65.00% for Label walk
# Finished 66.67% for Label walk
# Finished 68.33% for Label walk
# Finished 70.00% for Label walk
# Finished 71.67% for Label walk
# Finished 73.33% for Label walk
# Finished 75.00% for Label walk
# Finished 76.67% for Label walk
# Finished 78.33% for Label walk
# Finished 80.00% for Label walk
# Finished 81.67% for Label walk
# Finished 83.33% for Label walk
# Finished 85.00% for Label walk
# Finished 86.67% for Label walk
# Finished 88.33% for Label walk
# Finished 90.00% for Label walk
# Finished 91.67% for Label walk
# Finished 93.33% for Label walk
# Finished 95.00% for Label walk
# Finished 96.67% for Label walk
# Finished 98.33% for Label walk
# Finished 100.00% for Label walk

# %%
print(x_train.shape, y_train.shape, x_valid.shape, y_valid.shape)
# Out:
# (3634, 300, 52) (3634, 7) (911, 300, 52) (911, 7)

# %%
print(n_timesteps, n_features, n_outputs)
# Out:
# 300 52 7

# %%
from tensorflow.keras.layers import GlobalAveragePooling1D
model = Sequential()
model.add(LSTM(128, input_shape=(n_timesteps, n_features), return_sequences=True))
model.add(LSTM(96, return_sequences=True))
model.add(LSTM(64, return_sequences=True))
model.add(LSTM(32, return_sequences=True))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=16, kernel_size=3))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=8, kernel_size=3, activation='relu', kernel_regularizer=regularizers.L1L2(l1=0.001, l2=0.0001)))
model.add(MaxPooling1D(pool_size=2))
model.add(GlobalAveragePooling1D())
model.add(Dense(48, activation='relu', kernel_regularizer=regularizers.L1L2(l1=0.001, l2=0.0001)))
model.add(Dense(21, activation='relu', kernel_regularizer=regularizers.L1L2(l1=0.001, l2=0.0001)))
model.add(Dense(n_outputs, activation='softmax'))
model.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 300, 128)       │        92,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 300, 96)        │        86,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 300, 64)        │        41,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 300, 32)        │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 298, 64)        │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 149, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 147, 32)        │         6,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_6 (MaxPooling1D)  │ (None, 73, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_7 (Conv1D)               │ (None, 71, 16)         │         1,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_7 (MaxPooling1D)  │ (None, 35, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_8 (Conv1D)               │ (None, 33, 16)         │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_8 (MaxPooling1D)  │ (None, 16, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_9 (Conv1D)               │ (None, 14, 8)          │           392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_9 (MaxPooling1D)  │ (None, 7, 8)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_1      │ (None, 8)              │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 48)             │           432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 21)             │         1,029 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 7)              │           154 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 249,431 (974.34 KB)
#  Trainable params: 249,431 (974.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
model_name = 'CNN_LSTM2.keras'
checkpoint = ModelCheckpoint(model_name, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=30,min_delta=0.0001, verbose=1)

# reduce_learningrate = ReduceLROnPlateau(monitor='val_loss',
#                               factor=0.2,
#                               patience=6,
#                               verbose=1,
#                               min_delta=0.0001)

callbacks_list = [checkpoint, early_stopping]

# %%
verbose, epochs, batch_size = 1, 300, 48
opt= Adam(0.0001)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
history=model.fit(
        x_train,
        y_train,verbose=verbose,
        batch_size=batch_size, epochs=epochs,
        validation_split=0.2,
        callbacks=callbacks_list)
# Out:
# Epoch 1/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.1554 - loss: 2.2091
# Epoch 1: val_accuracy improved from -inf to 0.23109, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 20s 249ms/step - accuracy: 0.1553 - loss: 2.2088 - val_accuracy: 0.2311 - val_loss: 2.1111
# Epoch 2/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.2377 - loss: 2.0591
# Epoch 2: val_accuracy improved from 0.23109 to 0.23934, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 227ms/step - accuracy: 0.2378 - loss: 2.0582 - val_accuracy: 0.2393 - val_loss: 1.8629
# Epoch 3/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.3010 - loss: 1.8083
# Epoch 3: val_accuracy improved from 0.23934 to 0.35351, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 15s 238ms/step - accuracy: 0.3010 - loss: 1.8076 - val_accuracy: 0.3535 - val_loss: 1.6591
# Epoch 4/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.4235 - loss: 1.6124
# Epoch 4: val_accuracy improved from 0.35351 to 0.41678, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 236ms/step - accuracy: 0.4240 - loss: 1.6118 - val_accuracy: 0.4168 - val_loss: 1.5216
# Epoch 5/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.5088 - loss: 1.4389
# Epoch 5: val_accuracy improved from 0.41678 to 0.62724, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.5095 - loss: 1.4379 - val_accuracy: 0.6272 - val_loss: 1.2903
# Epoch 6/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.6605 - loss: 1.2068
# Epoch 6: val_accuracy improved from 0.62724 to 0.65612, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 226ms/step - accuracy: 0.6608 - loss: 1.2061 - val_accuracy: 0.6561 - val_loss: 1.1586
# Epoch 7/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.6937 - loss: 1.1033
# Epoch 7: val_accuracy improved from 0.65612 to 0.68501, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 232ms/step - accuracy: 0.6939 - loss: 1.1026 - val_accuracy: 0.6850 - val_loss: 1.1574
# Epoch 8/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.7327 - loss: 1.0266
# Epoch 8: val_accuracy improved from 0.68501 to 0.73177, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 237ms/step - accuracy: 0.7329 - loss: 1.0258 - val_accuracy: 0.7318 - val_loss: 0.9680
# Epoch 9/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.7644 - loss: 0.8851
# Epoch 9: val_accuracy improved from 0.73177 to 0.75378, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 233ms/step - accuracy: 0.7644 - loss: 0.8852 - val_accuracy: 0.7538 - val_loss: 0.9232
# Epoch 10/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.7860 - loss: 0.8212
# Epoch 10: val_accuracy improved from 0.75378 to 0.75791, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 232ms/step - accuracy: 0.7861 - loss: 0.8212 - val_accuracy: 0.7579 - val_loss: 0.8856
# Epoch 11/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.8170 - loss: 0.7626
# Epoch 11: val_accuracy improved from 0.75791 to 0.78817, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 230ms/step - accuracy: 0.8167 - loss: 0.7631 - val_accuracy: 0.7882 - val_loss: 0.8196
# Epoch 12/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7922 - loss: 0.7619
# Epoch 12: val_accuracy did not improve from 0.78817
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.7922 - loss: 0.7622 - val_accuracy: 0.7593 - val_loss: 0.8842
# Epoch 13/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7673 - loss: 0.8783
# Epoch 13: val_accuracy did not improve from 0.78817
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.7677 - loss: 0.8771 - val_accuracy: 0.7689 - val_loss: 0.8469
# Epoch 14/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8046 - loss: 0.7638
# Epoch 14: val_accuracy improved from 0.78817 to 0.79505, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 234ms/step - accuracy: 0.8047 - loss: 0.7638 - val_accuracy: 0.7950 - val_loss: 0.8058
# Epoch 15/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.8117 - loss: 0.7240
# Epoch 15: val_accuracy did not improve from 0.79505
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 233ms/step - accuracy: 0.8116 - loss: 0.7242 - val_accuracy: 0.7937 - val_loss: 0.7991
# Epoch 16/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8097 - loss: 0.7226
# Epoch 16: val_accuracy did not improve from 0.79505
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 233ms/step - accuracy: 0.8098 - loss: 0.7225 - val_accuracy: 0.7950 - val_loss: 0.7398
# Epoch 17/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.8382 - loss: 0.6778
# Epoch 17: val_accuracy improved from 0.79505 to 0.82256, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 228ms/step - accuracy: 0.8381 - loss: 0.6779 - val_accuracy: 0.8226 - val_loss: 0.6827
# Epoch 18/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8349 - loss: 0.6468
# Epoch 18: val_accuracy did not improve from 0.82256
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 235ms/step - accuracy: 0.8350 - loss: 0.6467 - val_accuracy: 0.8212 - val_loss: 0.6968
# Epoch 19/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.8437 - loss: 0.6329
# Epoch 19: val_accuracy did not improve from 0.82256
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 232ms/step - accuracy: 0.8437 - loss: 0.6332 - val_accuracy: 0.7964 - val_loss: 0.7469
# Epoch 20/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.8574 - loss: 0.6031
# Epoch 20: val_accuracy did not improve from 0.82256
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 228ms/step - accuracy: 0.8574 - loss: 0.6031 - val_accuracy: 0.8212 - val_loss: 0.6799
# Epoch 21/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.8455 - loss: 0.6209
# Epoch 21: val_accuracy did not improve from 0.82256
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 228ms/step - accuracy: 0.8456 - loss: 0.6208 - val_accuracy: 0.8088 - val_loss: 0.7073
# Epoch 22/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.8512 - loss: 0.6115
# Epoch 22: val_accuracy did not improve from 0.82256
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 233ms/step - accuracy: 0.8511 - loss: 0.6116 - val_accuracy: 0.7992 - val_loss: 0.6893
# Epoch 23/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8648 - loss: 0.5612
# Epoch 23: val_accuracy improved from 0.82256 to 0.82393, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 236ms/step - accuracy: 0.8648 - loss: 0.5614 - val_accuracy: 0.8239 - val_loss: 0.6714
# Epoch 24/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.8498 - loss: 0.5688
# Epoch 24: val_accuracy improved from 0.82393 to 0.83631, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 230ms/step - accuracy: 0.8499 - loss: 0.5690 - val_accuracy: 0.8363 - val_loss: 0.6172
# Epoch 25/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8867 - loss: 0.5209
# Epoch 25: val_accuracy improved from 0.83631 to 0.84457, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 232ms/step - accuracy: 0.8865 - loss: 0.5213 - val_accuracy: 0.8446 - val_loss: 0.6412
# Epoch 26/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8974 - loss: 0.4993
# Epoch 26: val_accuracy did not improve from 0.84457
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 231ms/step - accuracy: 0.8971 - loss: 0.4998 - val_accuracy: 0.8391 - val_loss: 0.6229
# Epoch 27/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.8894 - loss: 0.5031
# Epoch 27: val_accuracy did not improve from 0.84457
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 235ms/step - accuracy: 0.8891 - loss: 0.5037 - val_accuracy: 0.8363 - val_loss: 0.6151
# Epoch 28/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.8764 - loss: 0.5303
# Epoch 28: val_accuracy did not improve from 0.84457
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 232ms/step - accuracy: 0.8763 - loss: 0.5304 - val_accuracy: 0.8377 - val_loss: 0.6074
# Epoch 29/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.8513 - loss: 0.5714
# Epoch 29: val_accuracy did not improve from 0.84457
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 15s 239ms/step - accuracy: 0.8511 - loss: 0.5719 - val_accuracy: 0.7510 - val_loss: 0.8335
# Epoch 30/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8536 - loss: 0.5662
# Epoch 30: val_accuracy improved from 0.84457 to 0.86245, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 232ms/step - accuracy: 0.8538 - loss: 0.5658 - val_accuracy: 0.8624 - val_loss: 0.5679
# Epoch 31/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8963 - loss: 0.4825
# Epoch 31: val_accuracy did not improve from 0.86245
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 234ms/step - accuracy: 0.8963 - loss: 0.4826 - val_accuracy: 0.8611 - val_loss: 0.5328
# Epoch 32/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8967 - loss: 0.4732
# Epoch 32: val_accuracy did not improve from 0.86245
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 230ms/step - accuracy: 0.8965 - loss: 0.4739 - val_accuracy: 0.8473 - val_loss: 0.5904
# Epoch 33/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.8786 - loss: 0.5136
# Epoch 33: val_accuracy did not improve from 0.86245
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 226ms/step - accuracy: 0.8787 - loss: 0.5134 - val_accuracy: 0.8597 - val_loss: 0.5214
# Epoch 34/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.9109 - loss: 0.4357
# Epoch 34: val_accuracy did not improve from 0.86245
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 227ms/step - accuracy: 0.9107 - loss: 0.4363 - val_accuracy: 0.8253 - val_loss: 0.6183
# Epoch 35/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8940 - loss: 0.4619
# Epoch 35: val_accuracy improved from 0.86245 to 0.88308, saving model to CNN_LSTM2.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 231ms/step - accuracy: 0.8942 - loss: 0.4614 - val_accuracy: 0.8831 - val_loss: 0.4721
# Epoch 36/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.8934 - loss: 0.4621
# Epoch 36: val_accuracy did not improve from 0.88308
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 15s 238ms/step - accuracy: 0.8935 - loss: 0.4619 - val_accuracy: 0.8377 - val_loss: 0.5987
# Epoch 37/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8807 - loss: 0.4897
# Epoch 37: val_accuracy did not improve from 0.88308
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 234ms/step - accuracy: 0.8808 - loss: 0.4896 - val_accuracy: 0.8680 - val_loss: 0.5074
# Epoch 38/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8750 - loss: 0.4859
# Epoch 38: val_accuracy did not improve from 0.88308
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 230ms/step - accuracy: 0.8751 - loss: 0.4859 - val_accuracy: 0.8528 - val_loss: 0.5745
# Epoch 39/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.8926 - loss: 0.4665
# Epoch 39: val_accuracy did not improve from 0.88308
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s
val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 229ms/step - accuracy: 0.9852 - loss: 0.1854 - val_accuracy: 0.9464 - val_loss: 0.2676
# Epoch 159/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9797 - loss: 0.1948
# Epoch 159: val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 238ms/step - accuracy: 0.9796 - loss: 0.1949 - val_accuracy: 0.9409 - val_loss: 0.3299
# Epoch 160/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9722 - loss: 0.2276
# Epoch 160: val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 234ms/step - accuracy: 0.9722 - loss: 0.2274 - val_accuracy: 0.9491 - val_loss: 0.2503
# Epoch 161/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9820 - loss: 0.1904
# Epoch 161: val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 233ms/step - accuracy: 0.9819 - loss: 0.1908 - val_accuracy: 0.9409 - val_loss: 0.3153
# Epoch 162/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9844 - loss: 0.1958
# Epoch 162: val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 234ms/step - accuracy: 0.9845 - loss: 0.1956 - val_accuracy: 0.9560 - val_loss: 0.2438
# Epoch 163/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9914 - loss: 0.1643
# Epoch 163: val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 231ms/step - accuracy: 0.9913 - loss: 0.1645 - val_accuracy: 0.9519 - val_loss: 0.2605
# Epoch 164/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.9825 - loss: 0.1848
# Epoch 164: val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 228ms/step - accuracy: 0.9824 - loss: 0.1850 - val_accuracy: 0.9464 - val_loss: 0.2833
# Epoch 165/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9873 - loss: 0.1780
# Epoch 165: val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 235ms/step - accuracy: 0.9873 - loss: 0.1781 - val_accuracy: 0.9409 - val_loss: 0.2932
# Epoch 166/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9739 - loss: 0.2110
# Epoch 166: val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 231ms/step - accuracy: 0.9738 - loss: 0.2118 - val_accuracy: 0.8941 - val_loss: 0.4576
# Epoch 167/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9348 - loss: 0.3447
# Epoch 167: val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 237ms/step - accuracy: 0.9350 - loss: 0.3440 - val_accuracy: 0.9312 - val_loss: 0.3549
# Epoch 168/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9617 - loss: 0.2430
# Epoch 168: val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 234ms/step - accuracy: 0.9617 - loss: 0.2432 - val_accuracy: 0.9340 - val_loss: 0.3186
# Epoch 169/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9843 - loss: 0.1900
# Epoch 169: val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 237ms/step - accuracy: 0.9843 - loss: 0.1900 - val_accuracy: 0.9574 - val_loss: 0.2462
# Epoch 170/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9927 - loss: 0.1708
# Epoch 170: val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 15s 239ms/step - accuracy: 0.9926 - loss: 0.1709 - val_accuracy: 0.9298 - val_loss: 0.3902
# Epoch 171/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9676 - loss: 0.2451
# Epoch 171: val_accuracy did not improve from 0.96149
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 14s 230ms/step - accuracy: 0.9677 - loss: 0.2446 - val_accuracy: 0.9532 - val_loss: 0.2638
# Epoch 171: early stopping

# %%
import matplotlib.pyplot as plt

# Plot training & validation metrics
plt.figure(figsize=(18, 12))

# Plot training & validation accuracy
plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# evaluate model
model = tf.keras.models.load_model(model_name)
loss , accuracy = model.evaluate(x_valid, y_valid, batch_size=batch_size, verbose=1)
print("Loss: ",loss, "Accuracy: ",accuracy)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.9424 - loss: 0.2678
# Loss:  0.28622114658355713 Accuracy:  0.950603723526001

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the confusion matrix
y_pred = model.predict(x_valid)
cm = confusion_matrix(np.argmax(y_valid, axis=1), np.argmax(y_pred, axis=1), normalize='true')

# Plot the confusion matrix heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='.2f', xticklabels=["lie down", "fall", "bend", "run", "sitdown", "standup", "walk"], 
            yticklabels=["lie down", "fall", "bend", "run", "sitdown", "standup", "walk"])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Plot the accuracy curve
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot the loss curve
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step
