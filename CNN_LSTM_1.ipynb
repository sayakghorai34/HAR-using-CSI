# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, TimeDistributed, Conv1D, LSTM, MaxPooling1D, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import regularizers
from tensorflow.keras.layers import LeakyReLU
# from tensorflow_addons.optimizers import CyclicalLearningRate
import glob
import os
import csv

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    print(gpu)
    tf.config.experimental.set_memory_growth(gpu, True)
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
def merge_csi_label(csifile, labelfile, win_len=300, thrshd=0.6, step=50):
    activity = []
    with open(labelfile, 'r') as labelf:
        reader = csv.reader(labelf)
        for line in reader:
            label  = line[0]
            if label == 'NoActivity':
                activity.append(0)
            else:
                activity.append(1)
    activity = np.array(activity)
    csi = []
    with open(csifile, 'r') as csif:
        reader = csv.reader(csif)
        for line in reader:
            line_array = np.array([float(v) for v in line])
            # extract the amplitude only
            line_array = line_array[0:52]
            csi.append(line_array[np.newaxis,...])
    csi = np.concatenate(csi, axis=0)
    assert(csi.shape[0] == activity.shape[0])
    # screen the data with a window
    index = 0
    feature = []
    while index + win_len <= csi.shape[0]:
        cur_activity = activity[index:index+win_len]
        if np.sum(cur_activity)  <  thrshd * win_len:
            index += step
            continue
        cur_feature = np.zeros((1, win_len, 52))
        cur_feature[0] = csi[index:index+win_len, :]
        feature.append(cur_feature)
        index += step
    return np.concatenate(feature, axis=0)

# %%
def extract_csi_by_label(raw_folder, label, labels, save=False, win_len=300, thrshd=0.6, step=50):
    print('Starting Extract CSI for Label {}'.format(label))
    label = label.lower()
    if not label in labels:
        raise ValueError("The label {} should be among 'lie down','fall','bend','run','sitdown','standup','walk'".format(labels))
    data_path_pattern = os.path.join(raw_folder,label, 'user_*' + label + '*.csv')
    input_csv_files = sorted(glob.glob(data_path_pattern))
    # annot_csv_files = [os.path.basename(fname).replace('user_', 'annotation_user') for fname in input_csv_files]
    # annot_csv_files = [os.path.join(raw_folder, label, fname) for fname in annot_csv_files]
    annot_csv_files = os.path.join(raw_folder,label, 'Annotation_user_*' + label + '*.csv')
    annot_csv_files = sorted(glob.glob(annot_csv_files))
    feature = []
    index = 0
    for csi_file, label_file in zip(input_csv_files, annot_csv_files):
        index += 1
        if not os.path.exists(label_file):
            print('Warning! Label File {} doesn\'t exist.'.format(label_file))
            continue
        feature.append(merge_csi_label(csi_file, label_file, win_len=win_len, thrshd=thrshd, step=step))
        print('Finished {:.2f}% for Label {}'.format(index / len(input_csv_files) * 100,label))
    
    feat_arr = np.concatenate(feature, axis=0)
    if save:
        np.savez_compressed("X_{}.npz".format(label), feat_arr)
    # one hot
    feat_label = np.zeros((feat_arr.shape[0], len(labels)))
    feat_label[:, labels.index(label)] = 1
    return feat_arr, feat_label

# %%
def extract_csi(raw_folder, labels, save=False, win_len=300, thrshd=0.6, step=50):
    ans = []
    for label in labels:
        feature_arr, label_arr = extract_csi_by_label(raw_folder, label, labels, save, win_len, thrshd, step)
        ans.append(feature_arr)
        ans.append(label_arr)
    return tuple(ans)

# %%
class CSIModelConfig:
    def __init__(self, win_len=300, step=50, thrshd=0.6):
        self._win_len = win_len
        self._step = step
        self._thrshd = thrshd
        self._labels = ("lie down", "fall", "bend", "run", "sitdown", "standup", "walk")
        # self._downsample = downsample

    def preprocessing(self, raw_folder, save=False):
        numpy_tuple = extract_csi(raw_folder, self._labels, save, self._win_len, self._thrshd, self._step)
        # if self._downsample > 1:
        #     return tuple([v[:, ::self._downsample,...] if i%2 ==0 else v for i, v in enumerate(numpy_tuple)])
        return numpy_tuple
    
    def load_csi_data_from_files(self, np_files):
        if len(np_files) != 7:
            raise ValueError('There should be 7 numpy files for lie down, fall, bend, run, sitdown, standup, walk.')
        x = [np.load(f)['arr_0'] for f in np_files]
        # if self._downsample > 1:
        #     x = [arr[:,::self._downsample, :] for arr in x]
        y = [np.zeros((arr.shape[0], len(self._labels))) for arr in x]
        numpy_list = []
        for i in range(len(self._labels)):
            y[i][:,i] = 1
            numpy_list.append(x[i])
            numpy_list.append(y[i])
        return tuple(numpy_list)

# %%
def train_valid_split(numpy_tuple, train_portion=0.8, seed=200):
    np.random.seed(seed=seed)
    x_train = []
    x_valid = []
    y_valid = []
    y_train = []

    for i, x_arr in enumerate(numpy_tuple):
        index = np.random.permutation([i for i in range(x_arr.shape[0])])
        split_len = int(train_portion * x_arr.shape[0])
        x_train.append(x_arr[index[:split_len], ...])
        tmpy = np.zeros((split_len,7))
        tmpy[:, i] = 1
        y_train.append(tmpy)
        x_valid.append(x_arr[index[split_len:],...])
        tmpy = np.zeros((x_arr.shape[0]-split_len,7))
        tmpy[:, i] = 1
        y_valid.append(tmpy)
    
    x_train = np.concatenate(x_train, axis=0)
    y_train = np.concatenate(y_train, axis=0)
    x_valid = np.concatenate(x_valid, axis=0)
    y_valid = np.concatenate(y_valid, axis=0)

    index = np.random.permutation([i for i in range(x_train.shape[0])])
    x_train = x_train[index, ...]
    y_train = y_train[index, ...]
    return x_train, y_train, x_valid, y_valid

# %%
cfg = CSIModelConfig(win_len=300, step=50, thrshd=0.65)
numpy_tuple = cfg.preprocessing('CSI-HAR-Dataset', save=True)

x_lie_down, y_lie_down, x_fall, y_fall, x_bend, y_bend, x_run, y_run, x_sitdown, y_sitdown, x_standup, y_standup, x_walk, y_walk = numpy_tuple
x_train, y_train, x_valid, y_valid = train_valid_split((x_lie_down, x_fall, x_bend, x_run, x_sitdown, x_standup, x_walk),train_portion=0.8, seed=200)
n_timesteps, n_features, n_outputs = x_train.shape[1], x_train.shape[2], y_train.shape[1]
# Out:
# Starting Extract CSI for Label lie down
# Finished 1.67% for Label lie down
# Finished 3.33% for Label lie down
# Finished 5.00% for Label lie down
# Finished 6.67% for Label lie down
# Finished 8.33% for Label lie down
# Finished 10.00% for Label lie down
# Finished 11.67% for Label lie down
# Finished 13.33% for Label lie down
# Finished 15.00% for Label lie down
# Finished 16.67% for Label lie down
# Finished 18.33% for Label lie down
# Finished 20.00% for Label lie down
# Finished 21.67% for Label lie down
# Finished 23.33% for Label lie down
# Finished 25.00% for Label lie down
# Finished 26.67% for Label lie down
# Finished 28.33% for Label lie down
# Finished 30.00% for Label lie down
# Finished 31.67% for Label lie down
# Finished 33.33% for Label lie down
# Finished 35.00% for Label lie down
# Finished 36.67% for Label lie down
# Finished 38.33% for Label lie down
# Finished 40.00% for Label lie down
# Finished 41.67% for Label lie down
# Finished 43.33% for Label lie down
# Finished 45.00% for Label lie down
# Finished 46.67% for Label lie down
# Finished 48.33% for Label lie down
# Finished 50.00% for Label lie down
# Finished 51.67% for Label lie down
# Finished 53.33% for Label lie down
# Finished 55.00% for Label lie down
# Finished 56.67% for Label lie down
# Finished 58.33% for Label lie down
# Finished 60.00% for Label lie down
# Finished 61.67% for Label lie down
# Finished 63.33% for Label lie down
# Finished 65.00% for Label lie down
# Finished 66.67% for Label lie down
# Finished 68.33% for Label lie down
# Finished 70.00% for Label lie down
# Finished 71.67% for Label lie down
# Finished 73.33% for Label lie down
# Finished 75.00% for Label lie down
# Finished 76.67% for Label lie down
# Finished 78.33% for Label lie down
# Finished 80.00% for Label lie down
# Finished 81.67% for Label lie down
# Finished 83.33% for Label lie down
# Finished 85.00% for Label lie down
# Finished 86.67% for Label lie down
# Finished 88.33% for Label lie down
# Finished 90.00% for Label lie down
# Finished 91.67% for Label lie down
# Finished 93.33% for Label lie down
# Finished 95.00% for Label lie down
# Finished 96.67% for Label lie down
# Finished 98.33% for Label lie down
# Finished 100.00% for Label lie down
# Starting Extract CSI for Label fall
# Finished 1.67% for Label fall
# Finished 3.33% for Label fall
# Finished 5.00% for Label fall
# Finished 6.67% for Label fall
# Finished 8.33% for Label fall
# Finished 10.00% for Label fall
# Finished 11.67% for Label fall
# Finished 13.33% for Label fall
# Finished 15.00% for Label fall
# Finished 16.67% for Label fall
# Finished 18.33% for Label fall
# Finished 20.00% for Label fall
# Finished 21.67% for Label fall
# Finished 23.33% for Label fall
# Finished 25.00% for Label fall
# Finished 26.67% for Label fall
# Finished 28.33% for Label fall
# Finished 30.00% for Label fall
# Finished 31.67% for Label fall
# Finished 33.33% for Label fall
# Finished 35.00% for Label fall
# Finished 36.67% for Label fall
# Finished 38.33% for Label fall
# Finished 40.00% for Label fall
# Finished 41.67% for Label fall
# Finished 43.33% for Label fall
# Finished 45.00% for Label fall
# Finished 46.67% for Label fall
# Finished 48.33% for Label fall
# Finished 50.00% for Label fall
# Finished 51.67% for Label fall
# Finished 53.33% for Label fall
# Finished 55.00% for Label fall
# Finished 56.67% for Label fall
# Finished 58.33% for Label fall
# Finished 60.00% for Label fall
# Finished 61.67% for Label fall
# Finished 63.33% for Label fall
# Finished 65.00% for Label fall
# Finished 66.67% for Label fall
# Finished 68.33% for Label fall
# Finished 70.00% for Label fall
# Finished 71.67% for Label fall
# Finished 73.33% for Label fall
# Finished 75.00% for Label fall
# Finished 76.67% for Label fall
# Finished 78.33% for Label fall
# Finished 80.00% for Label fall
# Finished 81.67% for Label fall
# Finished 83.33% for Label fall
# Finished 85.00% for Label fall
# Finished 86.67% for Label fall
# Finished 88.33% for Label fall
# Finished 90.00% for Label fall
# Finished 91.67% for Label fall
# Finished 93.33% for Label fall
# Finished 95.00% for Label fall
# Finished 96.67% for Label fall
# Finished 98.33% for Label fall
# Finished 100.00% for Label fall
# Starting Extract CSI for Label bend
# Finished 1.67% for Label bend
# Finished 3.33% for Label bend
# Finished 5.00% for Label bend
# Finished 6.67% for Label bend
# Finished 8.33% for Label bend
# Finished 10.00% for Label bend
# Finished 11.67% for Label bend
# Finished 13.33% for Label bend
# Finished 15.00% for Label bend
# Finished 16.67% for Label bend
# Finished 18.33% for Label bend
# Finished 20.00% for Label bend
# Finished 21.67% for Label bend
# Finished 23.33% for Label bend
# Finished 25.00% for Label bend
# Finished 26.67% for Label bend
# Finished 28.33% for Label bend
# Finished 30.00% for Label bend
# Finished 31.67% for Label bend
# Finished 33.33% for Label bend
# Finished 35.00% for Label bend
# Finished 36.67% for Label bend
# Finished 38.33% for Label bend
# Finished 40.00% for Label bend
# Finished 41.67% for Label bend
# Finished 43.33% for Label bend
# Finished 45.00% for Label bend
# Finished 46.67% for Label bend
# Finished 48.33% for Label bend
# Finished 50.00% for Label bend
# Finished 51.67% for Label bend
# Finished 53.33% for Label bend
# Finished 55.00% for Label bend
# Finished 56.67% for Label bend
# Finished 58.33% for Label bend
# Finished 60.00% for Label bend
# Finished 61.67% for Label bend
# Finished 63.33% for Label bend
# Finished 65.00% for Label bend
# Finished 66.67% for Label bend
# Finished 68.33% for Label bend
# Finished 70.00% for Label bend
# Finished 71.67% for Label bend
# Finished 73.33% for Label bend
# Finished 75.00% for Label bend
# Finished 76.67% for Label bend
# Finished 78.33% for Label bend
# Finished 80.00% for Label bend
# Finished 81.67% for Label bend
# Finished 83.33% for Label bend
# Finished 85.00% for Label bend
# Finished 86.67% for Label bend
# Finished 88.33% for Label bend
# Finished 90.00% for Label bend
# Finished 91.67% for Label bend
# Finished 93.33% for Label bend
# Finished 95.00% for Label bend
# Finished 96.67% for Label bend
# Finished 98.33% for Label bend
# Finished 100.00% for Label bend
# Starting Extract CSI for Label run
# Finished 1.67% for Label run
# Finished 3.33% for Label run
# Finished 5.00% for Label run
# Finished 6.67% for Label run
# Finished 8.33% for Label run
# Finished 10.00% for Label run
# Finished 11.67% for Label run
# Finished 13.33% for Label run
# Finished 15.00% for Label run
# Finished 16.67% for Label run
# Finished 18.33% for Label run
# Finished 20.00% for Label run
# Finished 21.67% for Label run
# Finished 23.33% for Label run
# Finished 25.00% for Label run
# Finished 26.67% for Label run
# Finished 28.33% for Label run
# Finished 30.00% for Label run
# Finished 31.67% for Label run
# Finished 33.33% for Label run
# Finished 35.00% for Label run
# Finished 36.67% for Label run
# Finished 38.33% for Label run
# Finished 40.00% for Label run
# Finished 41.67% for Label run
# Finished 43.33% for Label run
# Finished 45.00% for Label run
# Finished 46.67% for Label run
# Finished 48.33% for Label run
# Finished 50.00% for Label run
# Finished 51.67% for Label run
# Finished 53.33% for Label run
# Finished 55.00% for Label run
# Finished 56.67% for Label run
# Finished 58.33% for Label run
# Finished 60.00% for Label run
# Finished 61.67% for Label run
# Finished 63.33% for Label run
# Finished 65.00% for Label run
# Finished 66.67% for Label run
# Finished 68.33% for Label run
# Finished 70.00% for Label run
# Finished 71.67% for Label run
# Finished 73.33% for Label run
# Finished 75.00% for Label run
# Finished 76.67% for Label run
# Finished 78.33% for Label run
# Finished 80.00% for Label run
# Finished 81.67% for Label run
# Finished 83.33% for Label run
# Finished 85.00% for Label run
# Finished 86.67% for Label run
# Finished 88.33% for Label run
# Finished 90.00% for Label run
# Finished 91.67% for Label run
# Finished 93.33% for Label run
# Finished 95.00% for Label run
# Finished 96.67% for Label run
# Finished 98.33% for Label run
# Finished 100.00% for Label run
# Starting Extract CSI for Label sitdown
# Finished 1.67% for Label sitdown
# Finished 3.33% for Label sitdown
# Finished 5.00% for Label sitdown
# Finished 6.67% for Label sitdown
# Finished 8.33% for Label sitdown
# Finished 10.00% for Label sitdown
# Finished 11.67% for Label sitdown
# Finished 13.33% for Label sitdown
# Finished 15.00% for Label sitdown
# Finished 16.67% for Label sitdown
# Finished 18.33% for Label sitdown
# Finished 20.00% for Label sitdown
# Finished 21.67% for Label sitdown
# Finished 23.33% for Label sitdown
# Finished 25.00% for Label sitdown
# Finished 26.67% for Label sitdown
# Finished 28.33% for Label sitdown
# Finished 30.00% for Label sitdown
# Finished 31.67% for Label sitdown
# Finished 33.33% for Label sitdown
# Finished 35.00% for Label sitdown
# Finished 36.67% for Label sitdown
# Finished 38.33% for Label sitdown
# Finished 40.00% for Label sitdown
# Finished 41.67% for Label sitdown
# Finished 43.33% for Label sitdown
# Finished 45.00% for Label sitdown
# Finished 46.67% for Label sitdown
# Finished 48.33% for Label sitdown
# Finished 50.00% for Label sitdown
# Finished 51.67% for Label sitdown
# Finished 53.33% for Label sitdown
# Finished 55.00% for Label sitdown
# Finished 56.67% for Label sitdown
# Finished 58.33% for Label sitdown
# Finished 60.00% for Label sitdown
# Finished 61.67% for Label sitdown
# Finished 63.33% for Label sitdown
# Finished 65.00% for Label sitdown
# Finished 66.67% for Label sitdown
# Finished 68.33% for Label sitdown
# Finished 70.00% for Label sitdown
# Finished 71.67% for Label sitdown
# Finished 73.33% for Label sitdown
# Finished 75.00% for Label sitdown
# Finished 76.67% for Label sitdown
# Finished 78.33% for Label sitdown
# Finished 80.00% for Label sitdown
# Finished 81.67% for Label sitdown
# Finished 83.33% for Label sitdown
# Finished 85.00% for Label sitdown
# Finished 86.67% for Label sitdown
# Finished 88.33% for Label sitdown
# Finished 90.00% for Label sitdown
# Finished 91.67% for Label sitdown
# Finished 93.33% for Label sitdown
# Finished 95.00% for Label sitdown
# Finished 96.67% for Label sitdown
# Finished 98.33% for Label sitdown
# Finished 100.00% for Label sitdown
# Starting Extract CSI for Label standup
# Finished 1.67% for Label standup
# Finished 3.33% for Label standup
# Finished 5.00% for Label standup
# Finished 6.67% for Label standup
# Finished 8.33% for Label standup
# Finished 10.00% for Label standup
# Finished 11.67% for Label standup
# Finished 13.33% for Label standup
# Finished 15.00% for Label standup
# Finished 16.67% for Label standup
# Finished 18.33% for Label standup
# Finished 20.00% for Label standup
# Finished 21.67% for Label standup
# Finished 23.33% for Label standup
# Finished 25.00% for Label standup
# Finished 26.67% for Label standup
# Finished 28.33% for Label standup
# Finished 30.00% for Label standup
# Finished 31.67% for Label standup
# Finished 33.33% for Label standup
# Finished 35.00% for Label standup
# Finished 36.67% for Label standup
# Finished 38.33% for Label standup
# Finished 40.00% for Label standup
# Finished 41.67% for Label standup
# Finished 43.33% for Label standup
# Finished 45.00% for Label standup
# Finished 46.67% for Label standup
# Finished 48.33% for Label standup
# Finished 50.00% for Label standup
# Finished 51.67% for Label standup
# Finished 53.33% for Label standup
# Finished 55.00% for Label standup
# Finished 56.67% for Label standup
# Finished 58.33% for Label standup
# Finished 60.00% for Label standup
# Finished 61.67% for Label standup
# Finished 63.33% for Label standup
# Finished 65.00% for Label standup
# Finished 66.67% for Label standup
# Finished 68.33% for Label standup
# Finished 70.00% for Label standup
# Finished 71.67% for Label standup
# Finished 73.33% for Label standup
# Finished 75.00% for Label standup
# Finished 76.67% for Label standup
# Finished 78.33% for Label standup
# Finished 80.00% for Label standup
# Finished 81.67% for Label standup
# Finished 83.33% for Label standup
# Finished 85.00% for Label standup
# Finished 86.67% for Label standup
# Finished 88.33% for Label standup
# Finished 90.00% for Label standup
# Finished 91.67% for Label standup
# Finished 93.33% for Label standup
# Finished 95.00% for Label standup
# Finished 96.67% for Label standup
# Finished 98.33% for Label standup
# Finished 100.00% for Label standup
# Starting Extract CSI for Label walk
# Finished 1.67% for Label walk
# Finished 3.33% for Label walk
# Finished 5.00% for Label walk
# Finished 6.67% for Label walk
# Finished 8.33% for Label walk
# Finished 10.00% for Label walk
# Finished 11.67% for Label walk
# Finished 13.33% for Label walk
# Finished 15.00% for Label walk
# Finished 16.67% for Label walk
# Finished 18.33% for Label walk
# Finished 20.00% for Label walk
# Finished 21.67% for Label walk
# Finished 23.33% for Label walk
# Finished 25.00% for Label walk
# Finished 26.67% for Label walk
# Finished 28.33% for Label walk
# Finished 30.00% for Label walk
# Finished 31.67% for Label walk
# Finished 33.33% for Label walk
# Finished 35.00% for Label walk
# Finished 36.67% for Label walk
# Finished 38.33% for Label walk
# Finished 40.00% for Label walk
# Finished 41.67% for Label walk
# Finished 43.33% for Label walk
# Finished 45.00% for Label walk
# Finished 46.67% for Label walk
# Finished 48.33% for Label walk
# Finished 50.00% for Label walk
# Finished 51.67% for Label walk
# Finished 53.33% for Label walk
# Finished 55.00% for Label walk
# Finished 56.67% for Label walk
# Finished 58.33% for Label walk
# Finished 60.00% for Label walk
# Finished 61.67% for Label walk
# Finished 63.33% for Label walk
# Finished 65.00% for Label walk
# Finished 66.67% for Label walk
# Finished 68.33% for Label walk
# Finished 70.00% for Label walk
# Finished 71.67% for Label walk
# Finished 73.33% for Label walk
# Finished 75.00% for Label walk
# Finished 76.67% for Label walk
# Finished 78.33% for Label walk
# Finished 80.00% for Label walk
# Finished 81.67% for Label walk
# Finished 83.33% for Label walk
# Finished 85.00% for Label walk
# Finished 86.67% for Label walk
# Finished 88.33% for Label walk
# Finished 90.00% for Label walk
# Finished 91.67% for Label walk
# Finished 93.33% for Label walk
# Finished 95.00% for Label walk
# Finished 96.67% for Label walk
# Finished 98.33% for Label walk
# Finished 100.00% for Label walk

# %%
print(x_train.shape, y_train.shape, x_valid.shape, y_valid.shape)
# Out:
# (3634, 300, 52) (3634, 7) (911, 300, 52) (911, 7)

# %%
print(n_timesteps, n_features, n_outputs)
# Out:
# 300 52 7

# %%
from tensorflow.keras.layers import GlobalAveragePooling1D
model = Sequential()
model.add(LSTM(128, input_shape=(n_timesteps, n_features), return_sequences=True))
model.add(LSTM(64, return_sequences=True))
model.add(LSTM(32, return_sequences=True))
model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=32, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=16, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Conv1D(filters=8, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(GlobalAveragePooling1D())
model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.L1L2(l1=0.001, l2=0.0001)))
model.add(Dense(16, activation='relu', kernel_regularizer=regularizers.L1L2(l1=0.001, l2=0.0001)))
model.add(Dense(n_outputs, activation='softmax'))
model.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_46 (LSTM)                  │ (None, 300, 128)       │        92,672 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_47 (LSTM)                  │ (None, 300, 64)        │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_48 (LSTM)                  │ (None, 300, 32)        │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_38 (Conv1D)              │ (None, 298, 64)        │         6,208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_26 (MaxPooling1D) │ (None, 149, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_39 (Conv1D)              │ (None, 147, 32)        │         6,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_27 (MaxPooling1D) │ (None, 73, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_40 (Conv1D)              │ (None, 71, 16)         │         1,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_28 (MaxPooling1D) │ (None, 35, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_41 (Conv1D)              │ (None, 33, 16)         │           784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_29 (MaxPooling1D) │ (None, 16, 16)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_42 (Conv1D)              │ (None, 14, 8)          │           392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_30 (MaxPooling1D) │ (None, 7, 8)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d_2      │ (None, 8)              │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_36 (Dense)                │ (None, 32)             │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_37 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_38 (Dense)                │ (None, 7)              │           119 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 170,543 (666.18 KB)
#  Trainable params: 170,543 (666.18 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
model_name = 'CNN_LSTM1.keras'
checkpoint = ModelCheckpoint(model_name, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
early_stopping = EarlyStopping(monitor='val_loss', patience=20,min_delta=0.0001, verbose=1)

# reduce_learningrate = ReduceLROnPlateau(monitor='val_loss',
#                               factor=0.2,
#                               patience=6,
#                               verbose=1,
#                               min_delta=0.0001)

callbacks_list = [checkpoint, early_stopping]

# %%
verbose, epochs, batch_size = 1, 300, 48
opt= Adam(0.0001)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
history=model.fit(
        x_train,
        y_train,verbose=verbose,
        batch_size=batch_size, epochs=epochs,
        validation_split=0.2,
        callbacks=callbacks_list)
# Out:
# Epoch 1/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.1379 - loss: 2.0786
# Epoch 1: val_accuracy improved from -inf to 0.17194, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 212ms/step - accuracy: 0.1380 - loss: 2.0784 - val_accuracy: 0.1719 - val_loss: 2.0052
# Epoch 2/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.1665 - loss: 1.9785
# Epoch 2: val_accuracy improved from 0.17194 to 0.28748, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.1671 - loss: 1.9779 - val_accuracy: 0.2875 - val_loss: 1.8486
# Epoch 3/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.2780 - loss: 1.8597
# Epoch 3: val_accuracy improved from 0.28748 to 0.33012, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.2783 - loss: 1.8595 - val_accuracy: 0.3301 - val_loss: 1.8072
# Epoch 4/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.3399 - loss: 1.8301
# Epoch 4: val_accuracy improved from 0.33012 to 0.36314, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.3401 - loss: 1.8300 - val_accuracy: 0.3631 - val_loss: 1.7682
# Epoch 5/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.3660 - loss: 1.7943
# Epoch 5: val_accuracy improved from 0.36314 to 0.42228, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.3660 - loss: 1.7944 - val_accuracy: 0.4223 - val_loss: 1.7778
# Epoch 6/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.3990 - loss: 1.7644
# Epoch 6: val_accuracy did not improve from 0.42228
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.3992 - loss: 1.7644 - val_accuracy: 0.4154 - val_loss: 1.7256
# Epoch 7/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.4146 - loss: 1.7332
# Epoch 7: val_accuracy did not improve from 0.42228
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.4143 - loss: 1.7330 - val_accuracy: 0.3989 - val_loss: 1.6646
# Epoch 8/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.3705 - loss: 1.6816
# Epoch 8: val_accuracy did not improve from 0.42228
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.3711 - loss: 1.6810 - val_accuracy: 0.4209 - val_loss: 1.5519
# Epoch 9/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.4803 - loss: 1.4658
# Epoch 9: val_accuracy improved from 0.42228 to 0.49931, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.4808 - loss: 1.4654 - val_accuracy: 0.4993 - val_loss: 1.5188
# Epoch 10/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.5844 - loss: 1.3163
# Epoch 10: val_accuracy improved from 0.49931 to 0.62724, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.5848 - loss: 1.3150 - val_accuracy: 0.6272 - val_loss: 1.1850
# Epoch 11/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.6464 - loss: 1.1332
# Epoch 11: val_accuracy improved from 0.62724 to 0.64924, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.6463 - loss: 1.1329 - val_accuracy: 0.6492 - val_loss: 1.0519
# Epoch 12/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.6825 - loss: 1.0114
# Epoch 12: val_accuracy improved from 0.64924 to 0.66575, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.6825 - loss: 1.0114 - val_accuracy: 0.6657 - val_loss: 0.9940
# Epoch 13/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.6882 - loss: 0.9539
# Epoch 13: val_accuracy improved from 0.66575 to 0.71389, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 181ms/step - accuracy: 0.6883 - loss: 0.9536 - val_accuracy: 0.7139 - val_loss: 0.9384
# Epoch 14/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7249 - loss: 0.8838
# Epoch 14: val_accuracy improved from 0.71389 to 0.74003, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.7247 - loss: 0.8839 - val_accuracy: 0.7400 - val_loss: 0.8584
# Epoch 15/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.7631 - loss: 0.7773
# Epoch 15: val_accuracy did not improve from 0.74003
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 182ms/step - accuracy: 0.7630 - loss: 0.7777 - val_accuracy: 0.7400 - val_loss: 0.8545
# Epoch 16/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7376 - loss: 0.8531
# Epoch 16: val_accuracy improved from 0.74003 to 0.74140, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.7378 - loss: 0.8522 - val_accuracy: 0.7414 - val_loss: 0.8148
# Epoch 17/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.7853 - loss: 0.7245
# Epoch 17: val_accuracy improved from 0.74140 to 0.76479, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.7853 - loss: 0.7245 - val_accuracy: 0.7648 - val_loss: 0.7758
# Epoch 18/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7852 - loss: 0.7229
# Epoch 18: val_accuracy did not improve from 0.76479
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.7852 - loss: 0.7229 - val_accuracy: 0.7469 - val_loss: 0.8596
# Epoch 19/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.7885 - loss: 0.7479
# Epoch 19: val_accuracy improved from 0.76479 to 0.76754, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.7887 - loss: 0.7471 - val_accuracy: 0.7675 - val_loss: 0.7392
# Epoch 20/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8121 - loss: 0.6395
# Epoch 20: val_accuracy did not improve from 0.76754
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.8121 - loss: 0.6397 - val_accuracy: 0.7620 - val_loss: 0.7516
# Epoch 21/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8070 - loss: 0.6612
# Epoch 21: val_accuracy improved from 0.76754 to 0.79367, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.8071 - loss: 0.6608 - val_accuracy: 0.7937 - val_loss: 0.6800
# Epoch 22/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8280 - loss: 0.6088
# Epoch 22: val_accuracy improved from 0.79367 to 0.80055, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 180ms/step - accuracy: 0.8280 - loss: 0.6090 - val_accuracy: 0.8006 - val_loss: 0.6792
# Epoch 23/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8246 - loss: 0.6259
# Epoch 23: val_accuracy did not improve from 0.80055
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.8243 - loss: 0.6263 - val_accuracy: 0.7882 - val_loss: 0.6925
# Epoch 24/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8455 - loss: 0.5550
# Epoch 24: val_accuracy did not improve from 0.80055
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.8456 - loss: 0.5551 - val_accuracy: 0.7909 - val_loss: 0.6803
# Epoch 25/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8565 - loss: 0.5493
# Epoch 25: val_accuracy did not improve from 0.80055
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.8564 - loss: 0.5493 - val_accuracy: 0.8006 - val_loss: 0.6851
# Epoch 26/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8588 - loss: 0.5265
# Epoch 26: val_accuracy improved from 0.80055 to 0.80605, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.8588 - loss: 0.5266 - val_accuracy: 0.8061 - val_loss: 0.6394
# Epoch 27/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8545 - loss: 0.5031
# Epoch 27: val_accuracy did not improve from 0.80605
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.8545 - loss: 0.5033 - val_accuracy: 0.8033 - val_loss: 0.6661
# Epoch 28/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8545 - loss: 0.5282
# Epoch 28: val_accuracy improved from 0.80605 to 0.81155, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.8546 - loss: 0.5280 - val_accuracy: 0.8116 - val_loss: 0.6286
# Epoch 29/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8610 - loss: 0.5135
# Epoch 29: val_accuracy did not improve from 0.81155
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.8609 - loss: 0.5136 - val_accuracy: 0.7895 - val_loss: 0.7608
# Epoch 30/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8225 - loss: 0.6057
# Epoch 30: val_accuracy improved from 0.81155 to 0.83906, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.8228 - loss: 0.6047 - val_accuracy: 0.8391 - val_loss: 0.5555
# Epoch 31/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8669 - loss: 0.4862
# Epoch 31: val_accuracy did not improve from 0.83906
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.8669 - loss: 0.4863 - val_accuracy: 0.8006 - val_loss: 0.6338
# Epoch 32/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8578 - loss: 0.5001
# Epoch 32: val_accuracy did not improve from 0.83906
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.8577 - loss: 0.5004 - val_accuracy: 0.8308 - val_loss: 0.6045
# Epoch 33/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8557 - loss: 0.5188
# Epoch 33: val_accuracy did not improve from 0.83906
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.8557 - loss: 0.5188 - val_accuracy: 0.8171 - val_loss: 0.5918
# Epoch 34/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8326 - loss: 0.5881
# Epoch 34: val_accuracy improved from 0.83906 to 0.84182, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.8329 - loss: 0.5873 - val_accuracy: 0.8418 - val_loss: 0.5319
# Epoch 35/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8641 - loss: 0.4990
# Epoch 35: val_accuracy did not improve from 0.84182
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.8639 - loss: 0.4993 - val_accuracy: 0.8088 - val_loss: 0.5920
# Epoch 36/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8722 - loss: 0.4752
# Epoch 36: val_accuracy improved from 0.84182 to 0.84319, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.8723 - loss: 0.4750 - val_accuracy: 0.8432 - val_loss: 0.5347
# Epoch 37/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8852 - loss: 0.4409
# Epoch 37: val_accuracy improved from 0.84319 to 0.84732, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 184ms/step - accuracy: 0.8850 - loss: 0.4414 - val_accuracy: 0.8473 - val_loss: 0.5477
# Epoch 38/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8652 - loss: 0.4752
# Epoch 38: val_accuracy did not improve from 0.84732
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.8650 - loss: 0.4758 - val_accuracy: 0.8377 - val_loss: 0.5827
# Epoch 39/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8711 - loss: 0.4878
# Epoch 39: val_accuracy improved from 0.84732 to 0.85282, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.8710 - loss: 0.4877 - val_accuracy: 0.8528 - val_loss: 0.5172
# Epoch 40/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8908 - loss: 0.4196
# Epoch 40: val_accuracy improved from 0.85282 to 0.86107, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.8909 - loss: 0.4194 - val_accuracy: 0.8611 - val_loss: 0.4968
# Epoch 41/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8932 - loss: 0.4341
# Epoch 41: val_accuracy did not improve from 0.86107
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 174ms/step - accuracy: 0.8931 - loss: 0.4341 - val_accuracy: 0.8501 - val_loss: 0.5191
# Epoch 42/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.8763 - loss: 0.4389
# Epoch 42: val_accuracy did not improve from 0.86107
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.8765 - loss: 0.4387 - val_accuracy: 0.8281 - val_loss: 0.5530
# Epoch 43/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.8848 - loss: 0.4561
# Epoch 43: val_accuracy did not improve from 0.86107
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.8847 - loss: 0.4562 - val_accuracy: 0.8432 - val_loss: 0.5119
# Epoch 44/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8961 - loss: 0.4220
# Epoch 44: val_accuracy did not improve from 0.86107
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.8959 - loss: 0.4221 - val_accuracy: 0.8391 - val_loss: 0.5487
# Epoch 45/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8816 - loss: 0.4514
# Epoch 45: val_accuracy improved from 0.86107 to 0.87070, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.8817 - loss: 0.4510 - val_accuracy: 0.8707 - val_loss: 0.4705
# Epoch 46/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8888 - loss: 0.4022
# Epoch 46: val_accuracy did not improve from 0.87070
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.8888 - loss: 0.4024 - val_accuracy: 0.8693 - val_loss: 0.4702
# Epoch 47/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9009 - loss: 0.3887
# Epoch 47: val_accuracy did not improve from 0.87070
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.9008 - loss: 0.3892 - val_accuracy: 0.8597 - val_loss: 0.4920
# Epoch 48/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.8924 - loss: 0.4031
# Epoch 48: val_accuracy did not improve from 0.87070
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 174ms/step - accuracy: 0.8924 - loss: 0.4030 - val_accuracy: 0.8652 - val_loss: 0.4682
# Epoch 49/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8995 - loss: 0.3911
# Epoch 49: val_accuracy did not improve from 0.87070
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.8994 - loss: 0.3911 - val_accuracy: 0.8514 - val_loss: 0.5313
# Epoch 50/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8944 - loss: 0.3907
# Epoch 50: val_accuracy did not improve from 0.87070
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.8944 - loss: 0.3908 - val_accuracy: 0.8404 - val_loss: 0.5119
# Epoch 51/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9106 - loss: 0.3691
# Epoch 51: val_accuracy did not improve from 0.87070
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.9104 - loss: 0.3694 - val_accuracy: 0.8611 - val_loss: 0.4760
# Epoch 52/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9168 - loss: 0.3595
# Epoch 52: val_accuracy did not improve from 0.87070
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.9167 - loss: 0.3597 - val_accuracy: 0.8611 - val_loss: 0.4965
# Epoch 53/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9014 - loss: 0.3839
# Epoch 53: val_accuracy did not improve from 0.87070
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.9014 - loss: 0.3838 - val_accuracy: 0.8693 - val_loss: 0.4717
# Epoch 54/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8804 - loss: 0.4366
# Epoch 54: val_accuracy improved from 0.87070 to 0.87620, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.8806 - loss: 0.4363 - val_accuracy: 0.8762 - val_loss: 0.4955
# Epoch 55/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9105 - loss: 0.3575
# Epoch 55: val_accuracy improved from 0.87620 to 0.88171, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.9104 - loss: 0.3576 - val_accuracy: 0.8817 - val_loss: 0.4238
# Epoch 56/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9184 - loss: 0.3332
# Epoch 56: val_accuracy did not improve from 0.88171
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.9184 - loss: 0.3332 - val_accuracy: 0.8569 - val_loss: 0.4839
# Epoch 57/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9166 - loss: 0.3555
# Epoch 57: val_accuracy did not improve from 0.88171
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.9166 - loss: 0.3554 - val_accuracy: 0.8624 - val_loss: 0.4709
# Epoch 58/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9006 - loss: 0.3984
# Epoch 58: val_accuracy did not improve from 0.88171
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.9004 - loss: 0.3989 - val_accuracy: 0.8597 - val_loss: 0.5212
# Epoch 59/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.8929 - loss: 0.4136
# Epoch 59: val_accuracy did not improve from 0.88171
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.8931 - loss: 0.4132 - val_accuracy: 0.8817 - val_loss: 0.4167
# Epoch 60/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9226 - loss: 0.3395
# Epoch 60: val_accuracy improved from 0.88171 to 0.88858, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 181ms/step - accuracy: 0.9225 - loss: 0.3395 - val_accuracy: 0.8886 - val_loss: 0.4103
# Epoch 61/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9273 - loss: 0.3222
# Epoch 61: val_accuracy did not improve from 0.88858
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.9273 - loss: 0.3224 - val_accuracy: 0.8721 - val_loss: 0.5171
# Epoch 62/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9035 - loss: 0.3958
# Epoch 62: val_accuracy did not improve from 0.88858
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.9035 - loss: 0.3956 - val_accuracy: 0.8611 - val_loss: 0.4658
# Epoch 63/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9188 - loss: 0.3341
# Epoch 63: val_accuracy did not improve from 0.88858
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.9188 - loss: 0.3345 - val_accuracy: 0.8748 - val_loss: 0.4686
# Epoch 64/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9140 - loss: 0.3452
# Epoch 64: val_accuracy did not improve from 0.88858
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 181ms/step - accuracy: 0.9139 - loss: 0.3456 - val_accuracy: 0.8817 - val_loss: 0.4146
# Epoch 65/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9288 - loss: 0.3142
# Epoch 65: val_accuracy did not improve from 0.88858
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.9288 - loss: 0.3142 - val_accuracy: 0.8762 - val_loss: 0.4336
# Epoch 66/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9273 - loss: 0.3114
# Epoch 66: val_accuracy did not improve from 0.88858
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.9272 - loss: 0.3118 - val_accuracy: 0.8845 - val_loss: 0.4402
# Epoch 67/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9111 - loss: 0.3596
# Epoch 67: val_accuracy did not improve from 0.88858
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 180ms/step - accuracy: 0.9110 - loss: 0.3598 - val_accuracy: 0.8803 - val_loss: 0.4151
# Epoch 68/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9335 - loss: 0.2977
# Epoch 68: val_accuracy did not improve from 0.88858
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.9335 - loss: 0.2979 - val_accuracy: 0.8735 - val_loss: 0.4250
# Epoch 69/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9256 - loss: 0.3092
# Epoch 69: val_accuracy did not improve from 0.88858
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.9255 - loss: 0.3096 - val_accuracy: 0.8638 - val_loss: 0.4585
# Epoch 70/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9341 - loss: 0.3060
# Epoch 70: val_accuracy improved from 0.88858 to 0.90509, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.9341 - loss: 0.3059 - val_accuracy: 0.9051 - val_loss: 0.3847
# Epoch 71/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9408 - loss: 0.2895
# Epoch 71: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.9408 - loss: 0.2895 - val_accuracy: 0.8748 - val_loss: 0.4474
# Epoch 72/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9117 - loss: 0.3453
# Epoch 72: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.9117 - loss: 0.3454 - val_accuracy: 0.8762 - val_loss: 0.4862
# Epoch 73/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9312 - loss: 0.3004
# Epoch 73: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.9313 - loss: 0.3000 - val_accuracy: 0.8858 - val_loss: 0.4478
# Epoch 74/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9210 - loss: 0.3202
# Epoch 74: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.9209 - loss: 0.3205 - val_accuracy: 0.8776 - val_loss: 0.4128
# Epoch 75/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9295 - loss: 0.3004
# Epoch 75: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.9296 - loss: 0.3004 - val_accuracy: 0.8955 - val_loss: 0.3839
# Epoch 76/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9334 - loss: 0.2827
# Epoch 76: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 174ms/step - accuracy: 0.9334 - loss: 0.2828 - val_accuracy: 0.8900 - val_loss: 0.3594
# Epoch 77/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9425 - loss: 0.2733
# Epoch 77: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 186ms/step - accuracy: 0.9424 - loss: 0.2733 - val_accuracy: 0.8955 - val_loss: 0.4112
# Epoch 78/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9294 - loss: 0.3013
# Epoch 78: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 180ms/step - accuracy: 0.9292 - loss: 0.3016 - val_accuracy: 0.8721 - val_loss: 0.4441
# Epoch 79/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9215 - loss: 0.3443
# Epoch 79: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.9216 - loss: 0.3439 - val_accuracy: 0.8858 - val_loss: 0.3826
# Epoch 80/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9390 - loss: 0.2770
# Epoch 80: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.9389 - loss: 0.2773 - val_accuracy: 0.8845 - val_loss: 0.3929
# Epoch 81/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9351 - loss: 0.2931
# Epoch 81: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.9349 - loss: 0.2938 - val_accuracy: 0.8556 - val_loss: 0.5132
# Epoch 82/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.8811 - loss: 0.4499
# Epoch 82: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 185ms/step - accuracy: 0.8814 - loss: 0.4489 - val_accuracy: 0.8886 - val_loss: 0.4147
# Epoch 83/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9375 - loss: 0.2838
# Epoch 83: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.9375 - loss: 0.2840 - val_accuracy: 0.8501 - val_loss: 0.4978
# Epoch 84/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9314 - loss: 0.3098
# Epoch 84: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.9313 - loss: 0.3098 - val_accuracy: 0.8762 - val_loss: 0.4678
# Epoch 85/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9136 - loss: 0.3310
# Epoch 85: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.9137 - loss: 0.3309 - val_accuracy: 0.8900 - val_loss: 0.3934
# Epoch 86/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9249 - loss: 0.3116
# Epoch 86: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.9249 - loss: 0.3115 - val_accuracy: 0.8927 - val_loss: 0.3779
# Epoch 87/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9496 - loss: 0.2511
# Epoch 87: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 174ms/step - accuracy: 0.9496 - loss: 0.2510 - val_accuracy: 0.8927 - val_loss: 0.3979
# Epoch 88/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9412 - loss: 0.2737
# Epoch 88: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.9411 - loss: 0.2739 - val_accuracy: 0.8514 - val_loss: 0.5345
# Epoch 89/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8987 - loss: 0.3700
# Epoch 89: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.8990 - loss: 0.3694 - val_accuracy: 0.8803 - val_loss: 0.4045
# Epoch 90/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9505 - loss: 0.2502
# Epoch 90: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 174ms/step - accuracy: 0.9504 - loss: 0.2504 - val_accuracy: 0.8900 - val_loss: 0.4352
# Epoch 91/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9544 - loss: 0.2369
# Epoch 91: val_accuracy did not improve from 0.90509
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.9543 - loss: 0.2369 - val_accuracy: 0.8982 - val_loss: 0.3606
# Epoch 92/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9526 - loss: 0.2396
# Epoch 92: val_accuracy improved from 0.90509 to 0.92160, saving model to CNN_LSTM1.keras
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.9525 - loss: 0.2397 - val_accuracy: 0.9216 - val_loss: 0.3164
# Epoch 93/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9466 - loss: 0.2602
# Epoch 93: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.9466 - loss: 0.2603 - val_accuracy: 0.9037 - val_loss: 0.3620
# Epoch 94/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9402 - loss: 0.2644
# Epoch 94: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.9402 - loss: 0.2645 - val_accuracy: 0.9106 - val_loss: 0.3790
# Epoch 95/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9459 - loss: 0.2462
# Epoch 95: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.9458 - loss: 0.2466 - val_accuracy: 0.9106 - val_loss: 0.3499
# Epoch 96/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.8615 - loss: 0.5859
# Epoch 96: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.8616 - loss: 0.5850 - val_accuracy: 0.8872 - val_loss: 0.4151
# Epoch 97/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9315 - loss: 0.3013
# Epoch 97: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.9316 - loss: 0.3009 - val_accuracy: 0.9106 - val_loss: 0.3597
# Epoch 98/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9485 - loss: 0.2484
# Epoch 98: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.9484 - loss: 0.2485 - val_accuracy: 0.9078 - val_loss: 0.3951
# Epoch 99/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9472 - loss: 0.2623
# Epoch 99: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 174ms/step - accuracy: 0.9471 - loss: 0.2623 - val_accuracy: 0.8996 - val_loss: 0.3877
# Epoch 100/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9357 - loss: 0.2758
# Epoch 100: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.9356 - loss: 0.2762 - val_accuracy: 0.8693 - val_loss: 0.4885
# Epoch 101/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9307 - loss: 0.2863
# Epoch 101: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.9308 - loss: 0.2862 - val_accuracy: 0.8941 - val_loss: 0.4003
# Epoch 102/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9576 - loss: 0.2339
# Epoch 102: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 179ms/step - accuracy: 0.9576 - loss: 0.2340 - val_accuracy: 0.9092 - val_loss: 0.3868
# Epoch 103/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9526 - loss: 0.2533
# Epoch 103: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.9525 - loss: 0.2532 - val_accuracy: 0.8941 - val_loss: 0.4028
# Epoch 104/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9419 - loss: 0.2623
# Epoch 104: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.9419 - loss: 0.2622 - val_accuracy: 0.8886 - val_loss: 0.3832
# Epoch 105/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9451 - loss: 0.2508
# Epoch 105: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.9452 - loss: 0.2508 - val_accuracy: 0.9078 - val_loss: 0.3286
# Epoch 106/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9568 - loss: 0.2201
# Epoch 106: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.9568 - loss: 0.2202 - val_accuracy: 0.9147 - val_loss: 0.3332
# Epoch 107/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9417 - loss: 0.2716
# Epoch 107: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.9416 - loss: 0.2717 - val_accuracy: 0.9147 - val_loss: 0.3197
# Epoch 108/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.9452 - loss: 0.2622
# Epoch 108: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 177ms/step - accuracy: 0.9448 - loss: 0.2633 - val_accuracy: 0.8776 - val_loss: 0.4517
# Epoch 109/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.8963 - loss: 0.3895
# Epoch 109: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 178ms/step - accuracy: 0.8967 - loss: 0.3887 - val_accuracy: 0.8968 - val_loss: 0.3939
# Epoch 110/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9458 - loss: 0.2529
# Epoch 110: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 180ms/step - accuracy: 0.9459 - loss: 0.2529 - val_accuracy: 0.8968 - val_loss: 0.3539
# Epoch 111/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9527 - loss: 0.2380
# Epoch 111: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 180ms/step - accuracy: 0.9527 - loss: 0.2380 - val_accuracy: 0.9175 - val_loss: 0.3178
# Epoch 112/300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9604 - loss: 0.2229
# Epoch 112: val_accuracy did not improve from 0.92160
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 11s 180ms/step - accuracy: 0.9603 - loss: 0.2229 - val_accuracy: 0.9188 - val_loss: 0.3404
# Epoch 112: early stopping

# %%
import matplotlib.pyplot as plt

# Plot training & validation metrics
plt.figure(figsize=(18, 12))

# Plot training & validation accuracy
plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# evaluate model
model = tf.keras.models.load_model(model_name)
loss , accuracy = model.evaluate(x_test, y_test, batch_size=batch_size, verbose=1)
print("Loss: ",loss, "Accuracy: ",accuracy)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - accuracy: 0.9039 - loss: 0.3691
# Loss:  0.3529023826122284 Accuracy:  0.9088913202285767

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the confusion matrix
y_pred = model.predict(x_test)
cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1), normalize='true')

# Plot the confusion matrix heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='.2f', xticklabels=["lie down", "fall", "bend", "run", "sitdown", "standup", "walk"], 
            yticklabels=["lie down", "fall", "bend", "run", "sitdown", "standup", "walk"])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# Plot the accuracy curve
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot the loss curve
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step
